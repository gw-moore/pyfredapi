# %%
import pyfredapi as pf
from rich.pretty import pprint

# %%
pprint(pf.releases.get_releases())
# Out:
# {
# │   'realtime_start': '2023-04-01',
# │   'realtime_end': '2023-04-01',
# │   'order_by': 'release_id',
# │   'sort_order': 'asc',
# │   'count': 309,
# │   'offset': 0,
# │   'limit': 1000,
# │   'releases': [
# │   │   {
# │   │   │   'id': 9,
# │   │   │   'realtime_start': '2023-04-01',
# │   │   │   'realtime_end': '2023-04-01',
# │   │   │   'name': 'Advance Monthly Sales for Retail and Food Services',
# │   │   │   'press_release': True,
# │   │   │   'link': 'http://www.census.gov/retail/',
# ...

# %%
pprint(pf.releases.get_releases_dates())
# Out:
# {
# │   'realtime_start': '2023-01-01',
# │   'realtime_end': '9999-12-31',
# │   'order_by': 'release_date',
# │   'sort_order': 'desc',
# │   'count': 2238,
# │   'offset': 0,
# │   'limit': 1000,
# │   'release_dates': [
# │   │   {'release_id': 441, 'release_name': 'Coinbase Cryptocurrencies', 'date': '2023-04-01'},
# │   │   {'release_id': 101, 'release_name': 'FOMC Press Release', 'date': '2023-04-01'},
# │   │   {'release_id': 441, 'release_name': 'Coinbase Cryptocurrencies', 'date': '2023-03-31'},
# │   │   {'release_id': 86, 'release_name': 'Commercial Paper', 'date': '2023-03-31'},
# │   │   {'release_id': 72, 'release_name': 'Daily Treasury Inflation-Indexed Securities', 'date': '2023-03-31'},
# │   │   {'release_id': 279, 'release_name': 'Economic Policy Uncertainty', 'date': '2023-03-31'},
# │   │   {'release_id': 502, 'release_name': 'Euro Short Term Rate', 'date': '2023-03-31'},
# │   │   {'release_id': 378, 'release_name': 'Federal Funds Data', 'date': '2023-03-31'},
# ...

# %%
pprint(pf.releases.get_release(53))
# Out:
# {
# │   'realtime_start': '2023-04-02',
# │   'realtime_end': '2023-04-02',
# │   'releases': [
# │   │   {
# │   │   │   'id': 53,
# │   │   │   'realtime_start': '2023-04-02',
# │   │   │   'realtime_end': '2023-04-02',
# │   │   │   'name': 'Gross Domestic Product',
# │   │   │   'press_release': True,
# │   │   │   'link': 'https://www.bea.gov/data/gdp/gross-domestic-product'
# │   │   }
# │   ]
# }

# %%
pf.release
