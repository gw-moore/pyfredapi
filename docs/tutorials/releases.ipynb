# %% [markdown]
# # FRED Releases
#
# The `pyfredapi.releases` module has functions for requesting data about [FRED Releases](https://fred.stlouisfed.org/releases).

# %%
import pyfredapi as pf
from rich.pretty import pprint

# %%
all_releases = pf.get_releases()

# %%
print(f"Number of release = {all_releases['count']}")
# Out:
# Number of release = 314

# %%
releases = all_releases["releases"]

# %%
pprint(releases[0:3])
# Out:
# [
# │   {
# │   │   'id': 9,
# │   │   'realtime_start': '2023-09-02',
# │   │   'realtime_end': '2023-09-02',
# │   │   'name': 'Advance Monthly Sales for Retail and Food Services',
# │   │   'press_release': True,
# │   │   'link': 'http://www.census.gov/retail/',
# │   │   'notes': 'The U.S. Census Bureau conducts the Advance Monthly Retail Trade and Food Services Survey to provide an early estimate of monthly sales by kind of business for retail and food service firms located in the United States. Each month, questionnaires are mailed to a probability sample of approximately 4,700 employer firms selected from the larger Monthly Retail Trade Survey. Advance sales estimates are computed using a link relative estimator. For each detailed industry, we compute a ratio of current-to previous month weighted sales using data from units for which we have obtained usable responses for both the current and previous month. For each detailed industry, the advance total sales estimates for the current month is computed by multiplying this ratio by the preliminary sales estimate for the previous month (derived from the larger MRTS) at the appropriate industry level. Total estimates for broader industries are computed as the sum of the detailed industry estimates. The link relative estimate is used because imputation is not performed for most nonrespondents in MARTS. For a limited number of nonresponding companies that have influential effects on the estimates, sales may be estimated based on historical performance of that company. The monthly estimates are benchmarked to the annual survey estimates from the Annual Retail Trade Survey once available. The estimates are adjusted for seasonal variation and holiday and trading day differences. Additional information on MARTS and MRTS can be found on the Census Bureau website at: www.census.gov/retail.\r\nDescription of the survey as provided by the Census, https://census.gov/retail/marts/www/marts_current.pdf'
# │   },
# │   {
# │   │   'id': 10,
# │   │   'realtime_start': '2023-09-02',
# │   │   'realtime_end': '2023-09-02',
# │   │   'name': 'Consumer Price Index',
# │   │   'press_release': True,
# │   │   'link': 'http://www.bls.gov/cpi/'
# │   },
# │   {
# │   │   'id': 11,
# │   │   'realtime_start': '2023-09-02',
# │   │   'realtime_end': '2023-09-02',
# │   │   'name': 'Employment Cost Index',
# │   │   'press_release': True,
# │   │   'link': 'http://www.bls.gov/ncs/ect'
# │   }
# ]

# %%
employment_cost_index = pf.get_release(release_id="11")

# %%
pprint(employment_cost_index)
# Out:
# {
# │   'realtime_start': '2023-09-02',
# │   'realtime_end': '2023-09-02',
# │   'releases': [
# │   │   {
# │   │   │   'id': 11,
# │   │   │   'realtime_start': '2023-09-02',
# │   │   │   'realtime_end': '2023-09-02',
# │   │   │   'name': 'Employment Cost Index',
# │   │   │   'press_release': True,
# │   │   │   'link': 'http://www.bls.gov/ncs/ect'
# │   │   }
# │   ]
# }

# %%
pf.get_release_

# %%
pf.get_release_series(release_id="11")
# Out:
# {'realtime_start': '2023-09-02',
#  'realtime_end': '2023-09-02',
#  'order_by': 'series_id',
#  'sort_order': 'asc',
#  'count': 417,
#  'offset': 0,
#  'limit': 1000,
#  'seriess': [{'id': 'CIS1010000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in All industries and occupations (DISCONTINUED)',
#    'observation_start': '2001-01-01',
#    'observation_end': '2017-10-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2018-01-31 08:31:02-06',
#    'popularity': 3,
#    'group_popularity': 3,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits. See Footnote C on https://www.bls.gov/ect/cimapnote.htm\n\nThis series has been discontinued and will no longer be updated. It was a duplicate of the following series, which will continue to be updated: https://fred.stlouisfed.org/series/ECIALLCIV'},
#   {'id': 'CIS1013000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Manufacturing',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:37-05',
#    'popularity': 2,
#    'group_popularity': 2,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Education and health services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:37-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Education services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:56-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016110000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Elementary and secondary schools',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:56-05',
#    'popularity': 0,
#    'group_popularity': 0,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016120000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Junior colleges, colleges, universities, and professional schools',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:37-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Health care and social assistance',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:37-05',
#    'popularity': 1,
#    'group_popularity': 3,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016220000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Hospitals',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:37-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1016230000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Nursing and residential care facilities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1019200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Public administration',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS101G000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Goods-producing industries',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS101S000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for All Civilian workers in Service-providing industries',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1020000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in All industries and occupations',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:05-05',
#    'popularity': 32,
#    'group_popularity': 32,
#    'notes': 'See Footnote C onhttps://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1023000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Manufacturing',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 2,
#    'group_popularity': 2,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Education and health services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Education services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026110000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Elementary and secondary schools',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:38-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026120000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Junior colleges, colleges, universities, and professional schools',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Health care and social assistance',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:10-05',
#    'popularity': 3,
#    'group_popularity': 4,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026220000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Hospitals',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1026230000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Nursing and residential care facilities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIS1029200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Public administration',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIS102G000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Goods-producing industries',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIS102S000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for All Civilian workers in Service-providing industries',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:39-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS1030000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total benefits for All Civilian workers in All industries and occupations',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote C onhttps://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in All industries and occupations (DISCONTINUED)',
#    'observation_start': '2001-01-01',
#    'observation_end': '2017-10-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2018-01-31 08:31:01-06',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.\n\nThis series has been discontinued and will no longer be updated. It was a duplicate of the following series, which will continue to be updated: https://fred.stlouisfed.org/series/ECICOM'},
#   {'id': 'CIS2010000100000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Management, professional, and related',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 5,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000110000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Management, business, and financial',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 2,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000120000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Professional and related',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 3,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000200000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Sales and office',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:56-05',
#    'popularity': 0,
#    'group_popularity': 0,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000210000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Sales and related',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000220000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Office and administrative support',
#    'observation_start': '2005-10-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 2,
#    'group_popularity': 2,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000400000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Natural resources, construction, and maintenance',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:40-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000405000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Construction, extraction, farming, fishing, and forestry occupations',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000430000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Installation, maintenance, and repair',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:10-05',
#    'popularity': 7,
#    'group_popularity': 11,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000500000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Production, transportation, and material moving',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 5,
#    'group_popularity': 5,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000510000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Production',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 1,
#    'group_popularity': 2,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2010000520000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Transportation and material moving',
#    'observation_start': '2005-10-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:15-05',
#    'popularity': 4,
#    'group_popularity': 15,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2013000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Manufacturing (DISCONTINUED)',
#    'observation_start': '2001-01-01',
#    'observation_end': '2017-10-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2018-01-31 08:31:02-06',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.\n\nThis series has been discontinued and will no longer be updated. It was a duplicate of the following series, which will continue to be updated: https://fred.stlouisfed.org/series/ECIMANCOM'},
#   {'id': 'CIS2013211000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Aircraft manufacturing',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2014000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Trade, transportation, and utilities',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2014110000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Wholesale trade',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIS2014120000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Retail trade',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.'},
#   {'id': 'CIS2014300000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Transportation and warehousing',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 5,
#    'group_popularity': 8,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2014400000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Utilities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 1,
#    'group_popularity': 4,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2015100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Information',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 2,
#    'group_popularity': 2,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2015200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Finance and insurance',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS201520A000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Financial activities',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2015220000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Credit intermediation and related activities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2015240000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Insurance carriers and related activities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:42-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2015300000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Real estate and rental and leasing',
#    'observation_start': '2005-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:56-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Some estimates from September 2012 to December 2012 for this series were corrected on July 17, 2013. Details are available at https://www.bls.gov/bls/eci_corrections_043013.htm.'},
#   {'id': 'CIS2015400000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Professional, scientific, and technical services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:07-05',
#    'popularity': 15,
#    'group_popularity': 31,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS201540A000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Professional and business services',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 2,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2015600000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Administrative and support and waste management and remediation services',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2016000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Education and health services',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:15-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2016100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Education services',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.'},
#   {'id': 'CIS2016120000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Junior colleges, colleges, universities, and professional schools',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2016200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Health care and social assistance',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:09-05',
#    'popularity': 2,
#    'group_popularity': 2,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Includes ambulatory health services and social assistance, not shown separately.'},
#   {'id': 'CIS2016220000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Hospitals',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2016230000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Nursing and residential care facilities',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:56-05',
#    'popularity': 0,
#    'group_popularity': 0,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2017000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Leisure and hospitality',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:09-05',
#    'popularity': 3,
#    'group_popularity': 3,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with March 2001.'},
#   {'id': 'CIS2017200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Accommodations and food service',
#    'observation_start': '2003-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:43-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote V on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2018100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Other services, except public administration',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Historical data are available beginning with December 2005.'},
#   {'id': 'CIS201G000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Goods-producing industries',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 1,
#    'group_popularity': 4,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.Includes mining, construction, and manufacturing.'},
#   {'id': 'CIS201S000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation for Private industry workers in Service-providing industries',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 4,
#    'group_popularity': 7,
#    'notes': 'Includes wages, salaries, and employer costs for employee benefits.See Footnote H on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2020000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for Private industry workers in All industries and occupations (DISCONTINUED)',
#    'observation_start': '2001-01-01',
#    'observation_end': '2017-10-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2018-01-31 08:31:06-06',
#    'popularity': 3,
#    'group_popularity': 3,
#    'notes': 'This series has been discontinued and will no longer be updated. It was a duplicate of the following series, which will continue to be updated: https://fred.stlouisfed.org/series/ECIWAG'},
#   {'id': 'CIS2020000100000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for Private industry workers in Management, professional, and related',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2020000110000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for Private industry workers in Management, business, and financial',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2020000120000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for Private industry workers in Professional and related',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:44-05',
#    'popularity': 1,
#    'group_popularity': 4,
#    'notes': 'See Footnote T on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIS2020000200000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
# ...
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:51:20-05',
#    'popularity': 3,
#    'group_popularity': 3,
#    'notes': 'See Footnote 3 on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIU3026000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Education and health services',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 1,
#    'notes': 'New series. Historical data are available beginning with March 2001.'},
#   {'id': 'CIU3026100000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Education services',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:51:20-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIU3026105000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Schools',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 0,
#    'notes': 'See Footnote O on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIU3026110000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Elementary and secondary schools',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:51:20-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'CIU3026200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Health care and social assistance',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 1,
#    'notes': 'Includes ambulatory health services and social assistance, not shown separately. See Footnote 3 on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIU3026220000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Hospitals',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 0},
#   {'id': 'CIU3029200000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and salaries for State and local government workers in Public administration',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 1,
#    'notes': 'See Footnote 3 on https://www.bls.gov/ect/cimapnote.htm'},
#   {'id': 'CIU3030000000000I',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total benefits for State and local government workers in All industries and occupations',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:51:20-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'ECIALLCIV',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Total compensation: All Civilian',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:03-05',
#    'popularity': 54,
#    'group_popularity': 54},
#   {'id': 'ECIBEN',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Benefits: Private Industry Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:08-05',
#    'popularity': 7,
#    'group_popularity': 7,
#    'notes': 'On April 26, 2006, The Employment Cost Index will convert to the 2002 North American Industry Classification System (NAICS) and the 2000 Standard Occupational Classification System (SOC). In addition, several computational changes will be introduced, including rebasing all series to December 2005=100 from June 1989=100, the introduction of new employment weights and seasonal adjustment factors.\nFor more detailed information on NAICS and SOC, including background and definitions, please see the Bureau of Labor Statistics (BLS) websites: https://www.bls.gov/bls/naics.htm and http://www.bls.gov/soc/home.htm.'},
#   {'id': 'ECICOM',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Compensation: Private Industry Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:10-05',
#    'popularity': 9,
#    'group_popularity': 9,
#    'notes': 'On April 26, 2006, The Employment Cost Index will convert to the 2002 North American Industry Classification System (NAICS) and the 2000 Standard Occupational Classification System (SOC). In addition, several computational changes will be introduced, including rebasing all series to December 2005=100 from June 1989=100, the introduction of new employment weights and seasonal adjustment factors.\nFor more detailed information on NAICS and SOC, including background and definitions, please see the Bureau of Labor Statistics (BLS) websites: https://www.bls.gov/bls/naics.htm and http://www.bls.gov/soc/home.htm.'},
#   {'id': 'ECICONCOM',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Compensation: Private Industry Workers: Construction',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 3,
#    'group_popularity': 3},
#   {'id': 'ECICONWAG',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and Salaries: Private Industry Workers: Construction',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:04-05',
#    'popularity': 38,
#    'group_popularity': 38},
#   {'id': 'ECIGVTBEN',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Benefits: State and Local Government: All Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'ECIGVTCOM',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Compensation: State and Local Government: All Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:15-05',
#    'popularity': 4,
#    'group_popularity': 4},
#   {'id': 'ECIGVTWAG',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and Salaries: State and Local Government: All Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:07-05',
#    'popularity': 12,
#    'group_popularity': 12},
#   {'id': 'ECIMANBEN',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Benefits: Private Industry Workers: Manufacturing',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'ECIMANCOM',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Compensation: Private Industry Workers: Manufacturing',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:12-05',
#    'popularity': 5,
#    'group_popularity': 5},
#   {'id': 'ECIMANWAG',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and Salaries: Private Industry Workers: Manufacturing',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:06-05',
#    'popularity': 25,
#    'group_popularity': 25},
#   {'id': 'ECISRVBEN',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Benefits: Private Industry Workers: Service Occupations',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:52:06-05',
#    'popularity': 0,
#    'group_popularity': 0},
#   {'id': 'ECISRVCOM',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Compensation: Private Industry Workers: Service Occupations',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:19-05',
#    'popularity': 1,
#    'group_popularity': 1},
#   {'id': 'ECISRVWAG',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and Salaries: Private Industry Workers: Service Occupations',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index: Dec 2005=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-07-28 07:51:12-05',
#    'popularity': 2,
#    'group_popularity': 2},
#   {'id': 'ECIWAG',
#    'realtime_start': '2023-09-02',
#    'realtime_end': '2023-09-02',
#    'title': 'Employment Cost Index: Wages and Salaries: Private Industry Workers',
#    'observation_start': '2001-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Index Dec 2005=100',
#    'units_short': 'Index Dec 2005=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-07-28 07:51:02-05',
#    'popularity': 70,
#    'group_popularity': 70,
#    'notes': 'On April 26, 2006, The Employment Cost Index converted to the 2002 North American Industry Classification System (NAICS) and the 2000 Standard Occupational Classification System (SOC). In addition, several computational changes were introduced, including rebasing all series to December 2005=100 from June 1989=100, the introduction of new employment weights and seasonal adjustment factors.\r\nFor more detailed information on NAICS and SOC, including background and definitions, please see the Bureau of Labor Statistics (BLS) websites:\xa0https://www.bls.gov/bls/naics.htm (https://www.bls.gov/bls/naics.htm)\xa0and\xa0http://www.bls.gov/soc/home.htm (http://www.bls.gov/soc/home.htm).'}]}
